# %% [markdown]
# # Data ingestion & inspection

# %% [markdown]
# ### numpy + pandas

# %%
import numpy as np
import pandas as pd

# %%
df_airport = pd.read_csv('airports.csv', index_col=0, names = ['Airline ID', 'Name', 'City',   'Country' , 'IATA', 'ICAO', 'Latitude' , 'Longitude', 'Altitude' , 'Timezone' , 'DST', 'Tz database time zone',  'Type', 'Source' ])

df_airport
# Out:
#                                                    Name                City  \
# Airline ID
# 1                                        Goroka Airport              Goroka
# 2                                        Madang Airport              Madang
# 3                          Mount Hagen Kagamuga Airport         Mount Hagen
# 4                                        Nadzab Airport              Nadzab
# 5           Port Moresby Jacksons International Airport        Port Moresby
# 6                           Wewak International Airport               Wewak
# 7                                    Narsarsuaq Airport        Narssarssuaq
# 8                               Godthaab / Nuuk Airport            Godthaab
# 9                                 Kangerlussuaq Airport         Sondrestrom
# 10                                       Thule Air Base               Thule
# 11                                     Akureyri Airport            Akureyri
# ...

# %%
df_airport.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7184 entries, 0 to 7183
# Data columns (total 14 columns):
# Airline ID               7184 non-null int64
# Name                     7184 non-null object
# City                     7140 non-null object
# Country                  7184 non-null object
# IATA                     7182 non-null object
# ICAO                     7184 non-null object
# Latitude                 7184 non-null float64
# Longitude                7184 non-null float64
# Altitude                 7184 non-null int64
# Timezone                 7184 non-null object
# DST                      7184 non-null object
# Tz database time zone    7184 non-null object
# Type                     7184 non-null object
# Source                   7184 non-null object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 785.8+ KB

# %%
df_airport.info(verbose=True)

[print(x, 'has type', type(eval(x))) for x in ['df_airport', 'np_vals'] ]
# Out:
# df_airport has type <class 'pandas.core.frame.DataFrame'>
# np_vals has type <class 'numpy.ndarray'>
# [None, None]
