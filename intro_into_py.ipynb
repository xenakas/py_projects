# %% [markdown]
# # Intro into Pyton

# %% [markdown]
# ## Functions

# %%
# Create lists first and second
first = [11.25, 18.0, 20.0]
second = [10.75, 9.50]

# Paste together first and second: full
full=first+second

# Sort full in descending order: full_sorted
full_sorted=sorted(full,reverse=True)

# Print out full_sorted
print(full_sorted)
# Out:
# [20.0, 18.0, 11.25, 10.75, 9.5]

# %%
# string to experiment with: room
room = "poolhouse"

# Print out room and room_up
print(room.upper())

# Print out the number of o's in room
print(room.count("o"))
# Out:
# POOLHOUSE
# 3

# %%
# Create list areas
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

areas.append(14.5) #adds an element to the list it is called on
areas.reverse() #reverses the order of the elements in the list it is called on
areas.remove(18.0) #removes the first element of a list that matches the input

print(areas)

# Print out the index of the element 20.0
print(areas.index(20.0))

# Print out how often 14.5 appears in areas
print(areas.count(14.5))
# Out:
# [14.5, 9.5, 10.75, 20.0, 11.25]
# 3
# 1

# %%
from math import radians

phi=radians(12)

print(14*phi)
# Out:
# 2.9321531433504737

# %% [markdown]
# # Intermediate Python

# %% [markdown]
# ## Plots

# %%
# generate random integer values
import numpy.random as npr

# seed random number generator
npr.seed(1)

colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

# generate some integers
life_exp =  npr.gumbel(45, 20, 100)
gdp_cap = npr.normal(9000, 2000, 100)
pop = npr.randint(0, 20, 100)
col = npr.choice(colors, 100)
tf = npr.choice([True, False], 100)

# %%
import matplotlib.pyplot as plt 
plt.plot(gdp_cap,life_exp)

# Definition of tick_val and tick_lab
tick_val = [5000,10000]
tick_lab = ['5k','10k']

# Adapt the ticks on the x-axis
plt.xticks(tick_val, tick_lab)

plt.grid(True) 

plt.show()

# %%
import numpy as np

plt.scatter(gdp_cap, life_exp, s = np.array(pop) ** 2, c = col, alpha = 0.8)
# Put the x-axis on a logarithmic scale
plt.xscale('log')

# Add axis labels
plt.xlabel('GDP per Capita [in USD]') 
plt.ylabel('Life Expectancy [in years]')

# Add title
plt.title('World Development in 2007')

plt.text(4550, 171, 'hi there')

plt.show()

# %%
plt.hist(life_exp, bins=5)
#plt.show()
plt.hist(life_exp, bins=20)
plt.show()

# %%
plt.hist(life_exp, bins=5)
plt.show()
plt.hist(life_exp, bins=20)
plt.show()

# %% [markdown]
# ## Dictionaries

# %%
# Definition of countries and capital
countries = ['spain', 'france', 'germany', 'norway']
capitals = ['madrid', 'paris', 'berlin', 'oslo']

# Use ind_ger to print out capital of Germany
print(capitals[countries.index('germany')])
# Out:
# berlin

# %%
europe = dict()
europe = dict(zip(countries, capitals))
# Add italy to europe
europe['italy'] = 'rome'
del europe['france'] 
print(europe)
print(europe['norway'])
# Out:
# {'spain': 'madrid', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome'}
# oslo

# %%
print(europe.keys())
print('poland' in europe)
# Out:
# dict_keys(['spain', 'germany', 'norway', 'italy'])
# False

# %%
# Dictionary of dictionaries
subeurope = { 'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } }
subeurope['italy']={
    'capital':'rome',
    'population':59.83
}
print(subeurope['italy']['capital']
)
# Out:
# rome

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

my_dict = {
    'drives_right' : gdp_cap,
    'cars_per_cap' : life_exp,
    'true' : tf
}

cars = pd.DataFrame(my_dict)

# %%
# Specify row labels of cars
cars.index = col

print(cars.head(5))

print(cars[3:6])
# Out:
#    cars_per_cap  drives_right   true
# y     57.338327   9631.269894   True
# c     40.154803   4955.597568   True
# m    226.519449   8387.591975  False
# g     65.432316  10655.949285   True
# y     81.813584   9460.189471  False
#    cars_per_cap  drives_right   true
# g     65.432316  10655.949285   True
# y     81.813584   9460.189471  False
# b     91.684844  10524.022361   True

# %%
inf = pd.read_csv('/home/xenakas/Desktop/hw2/Inflation.csv', index_col = 0) #index_col, an argument of read_csv(), that you can use to specify which column in the CSV file should be used as a row labe
print(inf.shape)
print(inf.iloc[:,[4,7,11]].head(6))
# Out:
# (134, 15)
#              -1     3  Средняя инфляция перехода
# Страна
# Армения     4.6   7.3                        3.8
# Бразилия    4.9   8.4                       17.3
# Венгрия     9.2   6.7                       12.2
# Гана       11.7  13.1                       16.1
# Гватемала   5.6   6.6                        6.4
# Грузия      1.7  -0.9                        7.6

# %%
print(inf['Средняя инфляция перехода'].head(3)) # Print out country column as Pandas Series
print(inf[['Средняя инфляция перехода']].head(5)) # Print out country column as Pandas DataFrame
print(inf[['Средняя инфляция перехода', 'Средняя инфляция после перехода']].head(3))  # Print out DataFrame
# Out:
# Страна
# Армения      3.8
# Бразилия    17.3
# Венгрия     12.2
# Name: Средняя инфляция перехода, dtype: float64
#            Средняя инфляция перехода
# Страна
# Армения                          3.8
# Бразилия                        17.3
# Венгрия                         12.2
# Гана                            16.1
# Гватемала                        6.4
#           Средняя инфляция перехода  Средняя инфляция после перехода
# Страна
# Армения                         3.8                              6.0
# Бразилия                       17.3                              8.7
# Венгрия                        12.2                              4.8

# %% [markdown]
# ## loc and iloc
#
# **loc** is label-based, which means that you have to specify rows and columns based on their row and column labels.
#
# **iloc** is integer index based, so you have to specify rows and columns by their integer index.

# %%
print(cars.loc[['c', 'b'], 'drives_right'].head(3))
# Out:
# c    4955.597568
# c    9820.103294
# c    7658.675427
# Name: drives_right, dtype: float64

# %%
print(cars.iloc[1:5])
# Out:
#    cars_per_cap  drives_right   true
# c     40.154803   4955.597568   True
# m    226.519449   8387.591975  False
# g     65.432316  10655.949285   True
# y     81.813584   9460.189471  False

# %%
print(cars.iloc[[1,5]])
# Out:
#    cars_per_cap  drives_right  true
# c     40.154803   4955.597568  True
# b     91.684844  10524.022361  True

# %% [markdown]
#  ## Logic, Control Flow and Filtering

# %%
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

# my_house greater than 18.5 or smaller than 10
print(np.logical_or(my_house > 18.5,  my_house < 10)
)
# Both my_house and your_house smaller than 11
print( np.logical_and(my_house <11, your_house <11))
# Out:
# [False  True False  True]
# [False False False  True]

# %%
# Convert code to a one-liner
sel = cars[cars['true']]

# Print sel
print(sel.head(3))
# Out:
#    cars_per_cap  drives_right  true
# y     57.338327   9631.269894  True
# c     40.154803   4955.597568  True
# g     65.432316  10655.949285  True

# %%
cpc = cars["cars_per_cap"]
many_cars = cpc > 40
car_maniac = cars[many_cars]

# Print car_maniac
print(car_maniac.head(3))
# Out:
#    cars_per_cap  drives_right   true
# y     57.338327   9631.269894   True
# c     40.154803   4955.597568   True
# m    226.519449   8387.591975  False

# %%
cpc = cars['cars_per_cap']
between = np.logical_and(cpc > 20, cpc < 50)
medium = cars[between]

# Print medium
print(medium.head(3))
# Out:
#    cars_per_cap  drives_right   true
# c     40.154803   4955.597568   True
# m     42.102766   9238.017292  False
# r     30.116567   9755.127573   True

# %% [markdown]
# ## Loops

# %%
# Initialize offset
offset = -6

# Code the while loop
while offset != 0 :
    print("correcting...")
    if offset > 0:
        offset = offset - 1
    else: 
        offset = offset + 1
    print(offset)
# Out:
# correcting...
# -5
# correcting...
# -4
# correcting...
# -3
# correcting...
# -2
# correcting...
# -1
# correcting...
# 0

# %%
# areas list
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Change for loop to use enumerate() and update print()
for b, a in enumerate(areas) : # b - index
    print("room " + str(b) + ": " + str(a))
# Out:
# room 0: 11.25
# room 1: 18.0
# room 2: 20.0
# room 3: 10.75
# room 4: 9.5
